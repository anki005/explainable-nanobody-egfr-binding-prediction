# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Thesis EGFR Round 3\Dataset\EG-combined full sequence with id.csv", sep=",")
df.columns = df.columns.str.strip()
with open(r"D:\Thesis EGFR Round 3\Dataset\EG-combined ANARCII.fasta", "w") as f:
    for _, row in df.iterrows():
        f.write(f">{row['Nanobody_id']}\n")
        f.write(f"{row['igghAaSequence']}\n")

print("FASTA file created successfully!")
# Out:
# FASTA file created successfully!

# %%
df = pd.read_csv(r"D:\Thesis EGFR Round 3\Dataset\Clustering\clustering_cdrs1.csv", sep=",")
df.columns = df.columns.str.strip()
with open(r"D:\Thesis EGFR Round 3\Dataset\Clustering\clustering_cdrs1.fasta", "w") as f:
    for _, row in df.iterrows():
        f.write(f">{row['ID']}\n")
        f.write(f"{row['Concatenated_CDRs']}\n")

print("FASTA file created successfully!")
# Out:
# FASTA file created successfully!

# %% [markdown]
# For cluster-level explanations

# %%
df = pd.read_csv(r"D:\Thesis EGFR Round 3\CNN model\Hyperparameter tune\cdrs_all_cnn_optuna_clustering.csv", sep=",")
df.columns = df.columns.str.strip()
with open(r"D:\Thesis EGFR Round 3\CNN model\Hyperparameter tune\cdrs_all_cnn_optuna_clustering.fasta", "w") as f:
    for _, row in df.iterrows():
        f.write(f">{row['ID']}\n")
        f.write(f"{row['CDR_sequence']}\n")

print("FASTA file created successfully!")
# Out:
# FASTA file created successfully!
